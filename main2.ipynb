# %%
from pathlib import Path
from gixtpy2 import SpecularOmega
# %matplotlib inline

path = Path(r"C:\Users\Teddy\OneDrive - UCB-O365\Rogerslab3\Teddy\TPP Films\BTB-TPP\2024 Film Growth\Film 4 (east campus dsc)\GIWAXS\film1\alignment")
spec = SpecularOmega(path / "spec")
spec.plot(critical_angle=0.24)
# Out:
# Direct beam is at (892.0411358961516, 475.06075672878626)
# z₀ = 0
# Fit results:
#     ω₀ = (0.36585319585312526 ± 0.001284768430818123)°
#     dₛ = (149.08912721216828 ± 0.6710866305963815) mm
# (<Figure size 400x300 with 2 Axes>,
#  <Axes: label='Counts in row', xlabel='$\\omega\\ (\\degree)$', ylabel='Z (mm)'>)

# %%
spec.fit(z0=-.11)
fig, ax = spec.plot(critical_angle=[0.24, .195, .195])
ax.text(0.5, 1.8, "Yoneda Peaks", fontsize=10, color="white",
        verticalalignment='center', horizontalalignment='right', bbox=dict(facecolor='white', alpha=0))
ax.text(0.75, 1, "horizon", fontsize=10, color="white",
        verticalalignment='center', horizontalalignment='left', bbox=dict(facecolor='white', alpha=0), rotation=35)
ax.text(0.9, 2.5, "Yoneda", fontsize=10, color="white",
        verticalalignment='center', horizontalalignment='left', bbox=dict(facecolor='white', alpha=0), rotation=35)
fig.savefig("specular.png", bbox_inches="tight", dpi=900)
# Out:
# z₀ = -0.11
# Fit results:
#     ω₀ = (0.3441203772443469 ± 0.0012558231238886778)°
#     dₛ = (148.66339031251943 ± 0.6392231549184549) mm

# %% [markdown]
# <img src="http://gisaxs.com/images/5/52/GISAXS_geometry07t.png" width=800 height=400 style="background-color:white;padding:20px;"/>
