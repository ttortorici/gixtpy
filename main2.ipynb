# %%
from pathlib import Path
from gixtpy2 import Data
# %matplotlib widget

# data = Data(Path(r"C:\Users\Teddy\OneDrive - UCB-O365\Rogerslab3\Teddy\TPP Films\BTB-TPP\2024 Film Growth\Film 2\XRD\non-grazing on blank for comparison\tune\raw_tiffs"))

data_dir = Path(r"C:\Users\Teddy\OneDrive - UCB-O365\Rogerslab3\Teddy\XRD\east campus gixtpy attempt\manual_align_new_film")

data = Data(data_dir)
# Out:
# Did not find a direct beam file

# %%
fig, ax = data.plot(beam_width=0.8, title="")
# Out:
# 87180.51495838165
# (<Figure size 400x300 with 2 Axes>,
#  <Axes: label='Counts in row', xlabel='$\\omega\\ (\\degree)$', ylabel='Z (mm)'>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.savefig("specular.png", dpi=600, bbox_inches="tight")
